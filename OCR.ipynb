# %%
import pytesseract
import cv2
import matplotlib.pyplot as plt 
from PIL import Image

# %%
Image = cv2.imread("handwritten.jpg")
plt.imshow(Image)
plt.show
'''cv2.imshow("photo", Image)
cv2.waitKey(0)
cv2.destroyAllWindows()'''
# Out:
# 'cv2.imshow("photo", Image)\ncv2.waitKey(0)\ncv2.destroyAllWindows()'

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR/tesseract.exe'
string = pytesseract.image_to_string(Image)
print(string)
# Out:
#
#
#
#
#
#
# |it was the best of the times, it_was
# ithe worst of the times. it was the
# lage of wisdom , it was the_age of
# foolishness. it was the the epoch of
# Ibelief_, it was the epoch of incredul’
#
# \|
